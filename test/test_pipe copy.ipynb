# %%
from test_pipe import *

import nest_asyncio
nest_asyncio.apply()
# Out:
# Paper trading mode enabled.
# Connecting to IBKR at 127.0.0.1:7497 with client ID 1

# %%
# Example usage
ib_conn = IBKRConnection(live_trading=False)
ib_conn.connect()
ib = ib_conn.get_ib()
# print(f"Server time: {ib.reqCurrentTime()}")

strat = MovingAverageStrategy(conn=ib_conn, symbol='AAPL', fast_period=10, slow_period=30)
strat.run_strategy()

# ib_conn.disconnect()
# Out:
# Paper trading mode enabled.
# Connecting to IBKR at 127.0.0.1:7497 with client ID 1
# Connected to IBKR at 127.0.0.1:7497 with client ID 1
# Strategy base class initialized. <class 'ib_insync.ib.IB'>
# Moving Average Strategy initialized for AAPL (10/30 periods).
# Analysis: Fast MA: 272.86, Slow MA: 270.64, Signal: None
# No trade signal generated for AAPL.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: usfarm.nj; usfuture; cashfarm; usfarm; ushmds; secdefnj.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 10350, reqId 6: Connectivity with IBKR is temporarily unavailable. Please retry in 1 minute.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: usfarm.nj; usfarm; secdefnj. The following farms are not connected: usfarm.nj; usfuture; cashfarm; usfarm; ushmds; secdefnj.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: usfarm.nj; usfuture; cashfarm; usfarm; ushmds; secdefnj.
# Error 322, reqId 9: Error processing request.-'b1' : cause - Maximum number of account summary requests exceeded; desubscribe to previous request first

# %%
strat.plot_signals(strat.df)

# %%
strat.df.head()
# Out:
#                         date    open    high     low   close     volume  \
# 29 2025-12-05 10:00:00-05:00  280.16  281.14  279.68  280.07  2953173.0
# 30 2025-12-05 11:00:00-05:00  280.08  280.32  278.75  278.78  2216793.0
# 31 2025-12-05 12:00:00-05:00  278.77  279.45  278.05  279.38  2081581.0
# 32 2025-12-05 13:00:00-05:00  279.38  279.57  278.58  278.70  1536867.0
# 33 2025-12-05 14:00:00-05:00  278.69  279.45  278.65  278.88  1781534.0
#
#     average  barCount   SMA_10      SMA_30  Signal  Buy_Signal_Price  \
# 29  280.424     15314  280.764  282.720667       0               NaN
# 30  279.371     11932  280.227  282.761000       0               NaN
# 31  278.573     11451  280.021  282.805000       0               NaN
# 32  279.133      8509  279.814  282.801000       0               NaN
# 33  279.082     10444  279.668  282.780000       0               NaN
#
#     Sell_Signal_Price
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN

# %%
df = strat.test_strategy()

# %%
strat.run_strategy()
# Out:
# Analysis: Fast MA: 272.80, Slow MA: 270.95, Signal: None
# No trade signal generated for AAPL.

# %%
df.describe()
# Out:
#              open        high         low       close        volume  \
# count  383.000000  383.000000  383.000000  383.000000  3.830000e+02
# mean   265.032298  265.935849  264.148433  265.071723  3.578350e+06
# std     10.416537   10.476930   10.419313   10.441034  1.905542e+06
# min    246.000000  246.960000  244.650000  245.280000  1.134622e+06
# 25%    255.980000  256.650000  255.160000  256.065000  2.239666e+06
# 50%    267.510000  268.590000  266.430000  267.480000  3.203361e+06
# 75%    272.530000  273.875000  271.460000  272.770000  4.386082e+06
# max    287.850000  288.620000  286.030000  287.850000  1.516195e+07
#
#           average      barCount      SMA_10      SMA_30      Signal  \
# count  383.000000    383.000000  383.000000  383.000000  383.000000
# mean   265.065076  19222.488251  264.699266  263.663771   -0.002611
# std     10.444647   9705.809649   10.421127   10.548628    0.210940
# min    245.753000   6916.000000  245.091000  240.859333   -1.000000
# 25%    255.998500  12308.000000  255.373000  254.562500    0.000000
# 50%    267.691000  17362.000000  267.824000  265.400667    0.000000
# 75%    272.782000  23166.500000  271.333500  271.132500    0.000000
# max    287.386000  76469.000000  286.065000  282.805000    1.000000
#
#        Buy_Signal_Price  Sell_Signal_Price  Asset_Return  Strategy_Return
# count          8.000000           9.000000    382.000000       382.000000
# mean         262.372500         262.120000      1.045354         1.033649
# std            9.989112          10.153317      0.041160         0.017394
# min          249.430000         248.410000      0.967192         1.000000
# 25%          255.530000         254.940000      1.009789         1.022950
# 50%          260.965000         260.250000      1.054870         1.030228
# 75%          271.365000         268.540000      1.075907         1.054031
# max          275.000000         280.340000      1.135055         1.056445

# %%
df.head()
# Out:
#                         date    open    high     low   close      volume  \
# 29 2025-09-22 10:00:00-04:00  251.11  253.69  250.78  253.60  11037368.0
# 30 2025-09-22 11:00:00-04:00  253.62  256.64  253.38  256.05  15161947.0
# 31 2025-09-22 12:00:00-04:00  256.07  256.31  253.16  254.21   9615809.0
# 32 2025-09-22 13:00:00-04:00  254.21  254.94  253.52  254.11   4656936.0
# 33 2025-09-22 14:00:00-04:00  254.10  255.77  254.02  255.40   4687310.0
#
#     average  barCount   SMA_10      SMA_30  Signal  Buy_Signal_Price  \
# 29  252.303     63045  245.091  240.859333       0               NaN
# 30  255.078     76469  246.911  241.382333       0               NaN
# 31  254.424     50032  248.243  241.890000       0               NaN
# 32  254.273     26493  249.370  242.405000       0               NaN
# 33  255.105     25875  250.581  242.947000       0               NaN
#
#     Sell_Signal_Price  Asset_Return  Strategy_Return
# 29                NaN           NaN              NaN
# 30                NaN      1.009661              1.0
# 31                NaN      1.002405              1.0
# 32                NaN      1.002011              1.0
# 33                NaN      1.007098              1.0

# %%
ib_conn.disconnect()
# Out:
# Disconnecting from IBKR ...
